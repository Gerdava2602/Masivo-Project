# %% [markdown]
# # Database creation

# %% [markdown]
# ## Connection to the data base

# %% [markdown]
# To connect to the database you must use the following two commands in the terminal:
#
#     * Endpoint: psql -h team-82.cc7kkbiuuvan.us-east-2.rds.amazonaws.com -U postgres
#     * Password Postgres: UDTeEGStmt6TQJc4Rixm
#     * Password BD: Ds4ateam_82
#
# It is also important to validate that the following packages are installed:
#
#     * sqlalchemy
#     * ipython-sql
#     * scipy
#     * pgspecial

# %%
# instalación librerias
# !pip install  sqlalchemy
# !pip install  ipython-sql
# !pip install  scipy
# !pip install  pgspecial

# %%
#connection to the database using the libraries
# %load_ext sql
# %sql postgresql://team_82:Ds4ateam_82@team-82.cc7kkbiuuvan.us-east-2.rds.amazonaws.com/masivo_capital
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ## Tables creation

# %%
create table catalogo_horas (
    orden int, 
    hora_inicial float, 
    hora_final float, 
    descripcion varchar(255)
)

create table validaciones_cluster_3(
    fecha_clearing date, 
    linea_sae varchar(255),
    ruta_modificada varchar(255),
    vehiculo varchar(255),
    parada varchar(255),
    val_year varchar(255),
    val_month varchar(255),
    val_week varchar(255),
    range_hour varchar(255),
    demanda int,
    longitud float,
    latitud float, 
    cluster varchar(255)
)
create table localizacion_paraderos (
    index int,
    cenefa_paradero varchar(20),
    count  int,
    percent float,
    posx int,
    posy int,
    lat varchar(255),
    lon varchar(255)
)
create table actividades_cluster_3 
(
    index varchar(255),
    fecha date,
    numero_bus varchar(255),
    linea varchar(255),
    nodo varchar(255),
    descripcion varchar(225),
    hora varchar(255),
    dia_semana varchar(255),
    mes varchar(255),
    dia varchar(255),
    paradero_cenefa varchar(255),
    longitud float,
    latitud float, 
    cluster varchar(255),
    range_hour varchar(255),
    oferta varchar(255)
)

# %% [markdown]
# ### Creating views

# %%
# Creation view 'historica de demanda'
# %%sql
create view historico_demanda_v2 as
select c.*, p.longitud, p.latitud, p.cluster from (
select a.*, count(a.fecha_clearing) as demanda from (
select 
    fecha_claring::date as fecha_clearing,
    linea_sae,
    ruta_modificada,
    vehiculo,
    parada,
    val_year,
    val_month,
    extract(week from fecha_claring) as val_week,
    case 
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 0 and 0.25 then '00:00 - 00:15'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 0.26 and 0.5 then '00:15 - 00:30'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 0.51 and 0.75 then '00:30 - 00:45'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 0.76 and 1 then '00:45 - 01:00'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 1.01 and 1.25 then '01:00 - 01:15'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 1.26 and 1.5 then '01:15 - 01:30'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 1.51 and 1.75 then '01:30 - 01:45'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 1.76 and 2 then '01:45 - 02:00'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 2.01 and 2.25 then '02:00 - 02:15'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 2.26 and 2.5 then '02:15 - 02:30'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 2.51 and 2.75 then '02:30 - 02:45'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 2.76 and 3 then '02:45 - 03:00'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 3.01 and 3.25 then '03:00 - 03:15'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 3.26 and 3.5 then '03:15 - 03:30'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 3.51 and 3.75 then '03:30 - 03:45'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 3.76 and 4 then '03:45 - 04:00'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 4.01 and 4.25 then '04:00 - 04:15'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between
45'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 20.76 and 21 then '20:45 - 21:00'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 21.01 and 21.25 then '21:00 - 21:15'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 21.26 and 21.5 then '21:15 - 21:30'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 21.51 and 21.75 then '21:30 - 21:45'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 21.76 and 22 then '21:45 - 22:00'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 22.01 and 22.25 then '22:00 - 22:15'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 22.26 and 22.5 then '22:15 - 22:30'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 22.51 and 22.75 then '22:30 - 22:45'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 22.76 and 23 then '22:45 - 23:00'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 23.01 and 23.25 then '23:00 - 23:15'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 23.26 and 23.5 then '23:15 - 23:30'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 23.51 and 23.75 then '23:30 - 23:45'
                when extract(hour from hora_trx) + (extract(minute from hora_trx)/60) between 23.76 and 24 then '23:45 - 23:59'

    end as range_hour
    from validaciones_v2 
where val_month in (4,5)
) a 
group by 
    a.fecha_clearing,
    a.linea_sae,
    a.ruta_modificada,
    a.vehiculo,
    a.parada,
    a.val_year,
    a.val_month,
    a.val_week,
    a.range_hour
) c 
left join paraderos_cluster p
on c.parada = p.paradero

# %%
# Creation view 'historica de oferta'
# %%sql
crate view historico_oferta
select 
    fecha,
    numero_bus,
    linea,
    nodo,
    descripcion,
    hora,
    dia_semana,
    mes,
    día,
    paradero_cenefa,
    longitug,
    latitud,
    cluster,
    range_hour,
    count(fecha) * 80 
from (

select a.*,
case 
        when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 0 and 0.25 then '00:00 - 00:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 0.26 and 0.5 then '00:15 - 00:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 0.51 and 0.75 then '00:30 - 00:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 0.76 and 1 then '00:45 - 01:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 1.01 and 1.25 then '01:00 - 01:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 1.26 and 1.5 then '01:15 - 01:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 1.51 and 1.75 then '01:30 - 01:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 1.76 and 2 then '01:45 - 02:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 2.01 and 2.25 then '02:00 - 02:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 2.26 and 2.5 then '02:15 - 02:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 2.51 and 2.75 then '02:30 - 02:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 2.76 and 3 then '02:45 - 03:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 3.01 and 3.25 then '03:00 - 03:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 3.26 and 3.5 then '03:15 - 03:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 3.51 and 3.75 then '03:30 - 03:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 3.76 and 4 then '03:45 - 04:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 4.01 and 4.25 then '04:00 - 04:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 4.26 and 4.5 then '04:15 - 04:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 4.51 and 4.75 then '04:30 - 04:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 4.76 and 5 then '04:45 - 05:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 5.01 and 5.25 then '05:00 - 05:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 5.26 and 5.5 then '05:15 - 05:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 5.51 and 5.75 then '05:30 - 05:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 5.76 and 6 then '05:45 - 06:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 6.01 and 6.25 then '06:00 - 06:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 6.26 and 6.5 then '06:15 - 06:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 6.51 and 6.75 then '06:30 - 06:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 6.76 and 7 then '06:45 - 07:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 7.01 and 7.25 then '07:00 - 07:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 7.26 and 7.5 then '07:15 - 07:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 7.51 and 7.75 then '07:30 - 07:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 7.76 and 8 then '07:45 - 08:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 8.01 and 8.25 then '08:00 - 08:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 8.26 and 8.5 then '08:15 - 08:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 8.51 and 8.75 then '08:30 - 08:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 8.76 and 9 then '08:45 - 09:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 9.01 and 9.25 then '09:00 - 09:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 9.26 and 9.5 then '09:15 - 09:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 9.51 and 9.75 then '09:30 - 09:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 9.76 and 10 then '09:45 - 10:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 10.01 and 10.25 then '10:00 - 10:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 10.26 and 10.5 then '10:15 - 10:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 10.51 and 10.75 then '10:30 - 10:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 10.76 and 11 then '10:45 - 11:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 11.01 and 11.25 then '11:00 - 11:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 11.26 and 11.5 then '11:15 - 11:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 11.51 and 11.75 then '11:30 - 11:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 11.76 and 12 then '11:45 - 12:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 12.01 and 12.25 then '12:00 - 12:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 12.26 and 12.5 then '12:15 - 12:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 12.51 and 12.75 then '12:30 - 12:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 12.76 and 13 then '12:45 - 13:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 13.01 and 13.25 then '13:00 - 13:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 13.26 and 13.5 then '13:15 - 13:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 13.51 and 13.75 then '13:30 - 13:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 13.76 and 14 then '13:45 - 14:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 14.01 and 14.25 then '14:00 - 14:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 14.26 and 14.5 then '14:15 - 14:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 14.51 and 14.75 then '14:30 - 14:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 14.76 and 15 then '14:45 - 15:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 15.01 and 15.25 then '15:00 - 15:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 15.26 and 15.5 then '15:15 - 15:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 15.51 and 15.75 then '15:30 - 15:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 15.76 and 16 then '15:45 - 16:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 16.01 and 16.25 then '16:00 - 16:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 16.26 and 16.5 then '16:15 - 16:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 16.51 and 16.75 then '16:30 - 16:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 16.76 and 17 then '16:45 - 17:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 17.01 and 17.25 then '17:00 - 17:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 17.26 and 17.5 then '17:15 - 17:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 17.51 and 17.75 then '17:30 - 17:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 17.76 and 18 then '17:45 - 18:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 18.01 and 18.25 then '18:00 - 18:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 18.26 and 18.5 then '18:15 - 18:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 18.51 and 18.75 then '18:30 - 18:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 18.76 and 19 then '18:45 - 19:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 19.01 and 19.25 then '19:00 - 19:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 19.26 and 19.5 then '19:15 - 19:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 19.51 and 19.75 then '19:30 - 19:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 19.76 and 20 then '19:45 - 20:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 20.01 and 20.25 then '20:00 - 20:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 20.26 and 20.5 then '20:15 - 20:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 20.51 and 20.75 then '20:30 - 20:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 20.76 and 21 then '20:45 - 21:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 21.01 and 21.25 then '21:00 - 21:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 21.26 and 21.5 then '21:15 - 21:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 21.51 and 21.75 then '21:30 - 21:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 21.76 and 22 then '21:45 - 22:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 22.01 and 22.25 then '22:00 - 22:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 22.26 and 22.5 then '22:15 - 22:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 22.51 and 22.75 then '22:30 - 22:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 22.76 and 23 then '22:45 - 23:00'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 23.01 and 23.25 then '23:00 - 23:15'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 23.26 and 23.5 then '23:15 - 23:30'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 23.51 and 23.75 then '23:30 - 23:45'
                when extract(hour from hora_llegada) + (extract(minute from hora_llegada)/60) between 23.76 and 24 then '23:45 - 23:59'
        else 'na'
        end as range_hour
from actividades a 
where mes in (4,5)
) g
    group by 
    fecha,
    numero_bus,
    linea,
    nodo,
    descripcion,
    hora,
    dia_semana,
    mes,
    día,
    paradero_cenefa,
    longitug,
    latitud,
    cluster,
    range_hour
